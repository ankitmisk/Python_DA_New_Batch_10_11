# %% [markdown]
# # Python Introduction

# %% [markdown]
# ![Python-01%20%282%29.png](attachment:Python-01%20%282%29.png)

# %% [markdown]
# - Portable Language. It is a cross-platform language. ...
# - Standard Library. ...
# - High-Level Language. ...
# - Easy to learn and use. ...
# - Dynamic Language. ...
# - Extensible Language. ...
# - Interpreted Language. ...
# - Object-Oriented Programming Language.

# %% [markdown]
# # Python Introduction
# ## Python Introduction
# ### Python Introduction
# #### Python Introduction
# #### Python Introduction
# ###### Python Introduction
# ####### Python Introduction

# %%
name = 'Nayan'
print(name)
# Out:
# Nayan

# %%
print(12*10)
# Out:
# 120

# %%
s = 23
print(s)
# Out:
# 23

# %%
print(type(s))
# Out:
# <class 'int'>

# %%
var = 'Mohan'

print(var)
# Out:
# Mohan

# %%
print(type(var))
# Out:
# <class 'str'>

# %%
names = 'karan','mohan','ajay','ravi'

# %%
print(names)
# Out:
# ('karan', 'mohan', 'ajay', 'ravi')

# %%
print(type(names))
# Out:
# <class 'tuple'>

# %%
names = ('karan','mohini','ajay','ravi')

print(names)
# Out:
# ('karan', 'mohini', 'ajay', 'ravi')

# %%
print(type(names))
# Out:
# <class 'tuple'>

# %%
maths_marks = 98.7

print(maths_marks)
# Out:
# 98.7

# %%
print(type(maths_marks))
# Out:
# <class 'float'>

# %%
# complex 
data = 45 + 8j
print(data)
# Out:
# (45+8j)

# %%
print(type(data))
# Out:
# <class 'complex'>

# %%
# int,float,complex
# str,tuple

# %%
# list

a = [2,432,532,4356,'Mohan','Answer']

print(a)
# Out:
# [2, 432, 532, 4356, 'Mohan', 'Answer']

# %%
print(type(a))
# Out:
# <class 'list'>

# %%
abc = {2,453,532,34,357}


print(abc)
print(type(abc))
# Out:
# {2, 34, 532, 453, 357}
# <class 'set'>

# %%
a = {1,1,1,1,2,2,2,23,3,3}
print(a)
print(type(a))
# Out:
# {1, 2, 3, 23}
# <class 'set'>

# %%
# dictionary data type

# key and value data

a = {"Name":'Mohan','Roll No':23}

# %%
print(a)
# Out:
# {'Name': 'Mohan', 'Roll No': 23}

# %%
print(type(a))
# Out:
# <class 'dict'>

# %%
# int,float,complex
# str,tuple,list,set,dict
# bool,None

# %%
# bool

a  = True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
bd = None
print(bd)
# Out:
# None

# %%
print(type(bd))
# Out:
# <class 'NoneType'>

# %% [markdown]
# ![Python-data-structure.jpg](attachment:Python-data-structure.jpg)

# %%
print(12*10)
# Out:
# 120
